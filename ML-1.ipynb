# %%
import pandas as pd

# %%
d=pd.read_csv('CarPrice_Assignment.csv')

# %%
read
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
d.head(4)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# ...

# %%
d.tail(10)
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 195     196         -1      volvo 144ea      gas        std       four
# 196     197         -2      volvo 244dl      gas        std       four
# 197     198         -1        volvo 245      gas        std       four
# 198     199         -2      volvo 264gl      gas      turbo       four
# 199     200         -1     volvo diesel      gas      turbo       four
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 195   wagon        rwd          front      104.3  ...         141        mpfi
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
d.shape
# Out:
# (205, 26)

# %%
carbody=d["carbody"]

# %%
carbody.head(10)
# Out:
# 0    convertible
# 1    convertible
# 2      hatchback
# 3          sedan
# 4          sedan
# 5          sedan
# 6          sedan
# 7          wagon
# 8          sedan
# 9      hatchback
# Name: carbody, dtype: object

# %%
drvwh_carl=[["drivewheel","carlength"]]

# %% [raw]
# drvwh_carl.head(20)

# %%
d.isna()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     False      False    False     False       False       False    False
# 1     False      False    False     False       False       False    False
# 2     False      False    False     False       False       False    False
# 3     False      False    False     False       False       False    False
# 4     False      False    False     False       False       False    False
# ..      ...        ...      ...       ...         ...         ...      ...
# 200   False      False    False     False       False       False    False
# 201   False      False    False     False       False       False    False
# 202   False      False    False     False       False       False    False
# 203   False      False    False     False       False       False    False
# 204   False      False    False     False       False       False    False
#
# ...

# %%
d.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
d.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
d["symboling"].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
d[d==0].count()
# Out:
# car_ID               0
# symboling           67
# CarName              0
# fueltype             0
# aspiration           0
# doornumber           0
# carbody              0
# drivewheel           0
# enginelocation       0
# wheelbase            0
# carlength            0
# carwidth             0
# carheight            0
# curbweight           0
# enginetype           0
# cylindernumber       0
# enginesize           0
# fuelsystem           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %%
mean=d['car_ID'].mean()

# %%
mean
# Out:
# 103.0

# %% [markdown]
# mean=read['wheelbase'].mean()

# %%
d.mean()
# Out:
# /tmp/ipykernel_9249/1214089992.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.mean()
# car_ID                103.000000
# symboling               0.834146
# wheelbase              98.756585
# carlength             174.049268
# carwidth               65.907805
# carheight              53.724878
# curbweight           2555.565854
# enginesize            126.907317
# boreratio               3.329756
# stroke                  3.255415
# compressionratio       10.142537
# horsepower            104.117073
# peakrpm              5125.121951
# citympg                25.219512
# highwaympg             30.751220
# price               13276.710571
# dtype: float64

# %% [raw]
# calulating the mean

# %%
d.mean()
# Out:
# /tmp/ipykernel_9249/1214089992.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.mean()
# car_ID                103.000000
# symboling               0.834146
# wheelbase              98.756585
# carlength             174.049268
# carwidth               65.907805
# carheight              53.724878
# curbweight           2555.565854
# enginesize            126.907317
# boreratio               3.329756
# stroke                  3.255415
# compressionratio       10.142537
# horsepower            104.117073
# peakrpm              5125.121951
# citympg                25.219512
# highwaympg             30.751220
# price               13276.710571
# dtype: float64

# %%
mean=d['carwidth'].mean()
mean
# Out:
# 65.90780487804878

# %%
mean=d['carheight'].mean()

# %%
mean
# Out:
# 53.72487804878049

# %%
subset1=d[["carlength","carwidth","stroke","horsepower","highwaympg"]]

# %%
subset1
# Out:
#      wheelbase  carlength  carwidth  stroke  horsepower  highwaympg
# 0         88.6      168.8      64.1    2.68         111          27
# 1         88.6      168.8      64.1    2.68         111          27
# 2         94.5      171.2      65.5    3.47         154          26
# 3         99.8      176.6      66.2    3.40         102          30
# 4         99.4      176.6      66.4    3.40         115          22
# ..         ...        ...       ...     ...         ...         ...
# 200      109.1      188.8      68.9    3.15         114          28
# 201      109.1      188.8      68.8    3.15         160          25
# 202      109.1      188.8      68.9    2.87         134          23
# 203      109.1      188.8      68.9    3.40         106          27
# 204      109.1      188.8      68.9    3.15         114          25
#
# [205 rows x 6 columns]

# %%
subset1.head(100)
# Out:
#     wheelbase  carlength  carwidth  stroke  horsepower  highwaympg
# 0        88.6      168.8      64.1    2.68         111          27
# 1        88.6      168.8      64.1    2.68         111          27
# 2        94.5      171.2      65.5    3.47         154          26
# 3        99.8      176.6      66.2    3.40         102          30
# 4        99.4      176.6      66.4    3.40         115          22
# ..        ...        ...       ...     ...         ...         ...
# 95       94.5      165.6      63.8    3.29          69          37
# 96       94.5      165.3      63.8    3.29          69          37
# 97       94.5      170.2      63.8    3.29          69          37
# 98       95.1      162.4      63.8    3.29          69          37
# 99       97.2      173.4      65.2    3.47          97          34
#
# [100 rows x 6 columns]

# %%
subset2=d[["wheelbase","horsepower","carwidth","carlength","stroke"]]

# %%
subset2
# Out:
#      wheelbase  horsepower  carwidth  carlength  stroke
# 0         88.6         111      64.1      168.8    2.68
# 1         88.6         111      64.1      168.8    2.68
# 2         94.5         154      65.5      171.2    3.47
# 3         99.8         102      66.2      176.6    3.40
# 4         99.4         115      66.4      176.6    3.40
# ..         ...         ...       ...        ...     ...
# 200      109.1         114      68.9      188.8    3.15
# 201      109.1         160      68.8      188.8    3.15
# 202      109.1         134      68.9      188.8    2.87
# 203      109.1         106      68.9      188.8    3.40
# 204      109.1         114      68.9      188.8    3.15
#
# [205 rows x 5 columns]

# %%
subset3=d[d["fueltype"]=="gas"]

# %%
subset3
# Out:
#      car_ID  symboling               CarName fueltype aspiration doornumber  \
# 79       80          1         mitsubishi g4      gas      turbo        two
# 80       81          3  mitsubishi mirage g4      gas      turbo        two
# 82       83          3  mitsubishi outlander      gas      turbo        two
# 83       84          3         mitsubishi g4      gas      turbo        two
# 84       85          3  mitsubishi mirage g4      gas      turbo        two
# 87       88          1  mitsubishi outlander      gas      turbo       four
# 88       89         -1  mitsubishi mirage g4      gas        std       four
# 119     120          1      plymouth cricket      gas      turbo        two
# 124     125          3       plymouth duster      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 79   hatchback        fwd          front       93.0  ...          98
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# using train test split

# %% [markdown]
# using sklearn

# %%
d
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
X=d[d!='price']
y=d['price']

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,random_state=104,test_size=0.25,shuffle=True)

# %%
X_train
# Out:
#      car_ID  symboling                CarName fueltype aspiration doornumber  \
# 103     104          0            nissan otti      gas        std       four
# 157     158          0    toyota corolla 1200      gas        std       four
# 109     110          0       peugeot 504 (sw)      gas        std       four
# 160     161          0          toyota corona      gas        std       four
# 113     114          0            peugeot 504      gas        std       four
# ..      ...        ...                    ...      ...        ...        ...
# 127     128          3        porsche cayenne      gas        std        two
# 166     167          1  toyota corolla tercel      gas        std        two
# 142     143          0             subaru brz      gas        std       four
# 193     194          0      volkswagen dasher      gas        std       four
# 69       70          0          buick century   diesel      turbo        two
#
# ...

# %%
X_test
# Out:
#      car_ID  symboling                  CarName fueltype aspiration  \
# 197     198         -1                volvo 245      gas        std
# 90       91          1              nissan gt-r   diesel        std
# 5         6          2                 audi fox      gas        std
# 194     195         -2          volvo 145e (sw)      gas        std
# 91       92          1             nissan rogue      gas        std
# 143     144          0              subaru baja      gas        std
# 45       46          0      isuzu D-Max V-Cross      gas        std
# 169     170          2           toyota starlet      gas        std
# 156     157          0           toyota mark ii      gas        std
# 52       53          1          mazda rx2 coupe      gas        std
# 86       87          1        mitsubishi pajero      gas        std
# 158     159          0            toyota corona   diesel        std
# 95       96          1              nissan juke      gas        std
# ...

# %%
y_train
# Out:
# 103    13499.0
# 157     7198.0
# 109    12440.0
# 160     7738.0
# 113    16695.0
#         ...
# 127    34028.0
# 166     9538.0
# 142     7775.0
# 193    12290.0
# 69     28176.0
# Name: price, Length: 153, dtype: float64

# %%
y_test
# Out:
# 197    16515.000
# 90      7099.000
# 5      15250.000
# 194    12940.000
# 91      6649.000
# 143     9960.000
# 45      8916.500
# 169     9989.000
# 156     6938.000
# 52      6795.000
# 86      8189.000
# 158     7898.000
# 95      7799.000
# 34      7129.000
# 49     36000.000
# 18      5151.000
# 61     10595.000
# 97      7999.000
# 41     12945.000
# 73     40960.000
# 70     31600.000
# 28      8921.000
# 123     8921.000
# 167     8449.000
# 35      7295.000
# 84     14489.000
# 135    15510.000
# 58     15645.000
# 164     8238.000
# 134    15040.000
# 162     9258.000
# 64     11245.000
# 1      16500.000
# 117    18150.000
# 178    16558.000
# 51      6095.000
# 56     11845.000
# 9      17859.167
# 102    14399.000
# 185     8195.000
# 10     16430.000
# 78      6669.000
# 47     32250.000
# 20      6575.000
# 173     8948.000
# 150     5348.000
# 7      18920.000
# 99      8949.000
# 147    10198.000
# 152     6488.000
# 23      7957.000
# 120     6229.000
# ...

# %%
import matplotlib.pyplot as pylab

# %%
d.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as s

# %%
s.pairplot(subset1)

# %%
subset1=d.head(100)

# %%
s.pairplot(d,hue='fueltype')
