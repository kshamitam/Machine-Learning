# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Market_Basket.csv",header=None)
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
data.shape
# Out:
# (7501, 20)

# %%
data.isna().sum()
# Out:
# 0        0
# 1     1754
# 2     3112
# 3     4156
# 4     4972
# 5     5637
# 6     6132
# 7     6520
# 8     6847
# 9     7106
# 10    7245
# 11    7347
# 12    7414
# 13    7454
# 14    7476
# 15    7493
# 16    7497
# 17    7497
# 18    7498
# 19    7500
# dtype: int64

# %%
from collections import Counter

# %%
items = data[0].value_counts()
items
# Out:
# mineral water        577
# burgers              576
# turkey               458
# chocolate            391
# frozen vegetables    373
#                     ...
# cauliflower            1
# ketchup                1
# cream                  1
# body spray             1
# oatmeal                1
# Name: 0, Length: 115, dtype: int64

# %%
import matplotlib.pylab as plt
import seaborn as sb

# %%
for i in range (0,20):
    plt.figure(figsize=(15, 6))
    sb.countplot(data=data, x=data.columns[i],order = data[data.columns[i]].value_counts().index)
    plt.xticks(rotation=90, fontsize=5)
    plt.subplots_adjust(wspace=200)
    plt.show()

# %%
trans=[]
for i in range(0,7501):
    trans.append([str(data.values[i,j])for j in range(0,20)])
    
trans
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
pip install apyori
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5975 sha256=fdfc3e7c1120f14596a6cdfda765bca118fb5647e5bfa1c7f9ba49dc969a7a92
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\c4\1a\79\20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script apyori-run.exe is installed in 'C:\Users\HP\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from apyori import apriori
rules= apriori(trans, min_support=0.05, min_confidence=0.5, min_lift=0.5, min_length=2)
rules
# Out:
# <generator object apriori at 0x0000029017D209E0>

# %%
final = list(rules)
final
# Out:
# [RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan', 'burgers'}), support=0.0871883748833489, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cake', 'nan'}), support=0.08105585921877083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chicken', 'nan'}), support=0.05999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
# ...

# %%
for i in final:
    print(i)
    print("/n")
# Out:
# RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)])
# /n
# RelationRecord(items=frozenset({'nan', 'burgers'}), support=0.0871883748833489, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)])
# /n
# RelationRecord(items=frozenset({'cake', 'nan'}), support=0.08105585921877083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)])
# /n
# RelationRecord(items=frozenset({'chicken', 'nan'}), support=0.05999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)])
# /n
# ...

# %%
np= pd.DataFrame(final)
np = np.drop(columns=['ordered_statistics'])
np = np.drop(columns=['support'])

np
# Out:
#                               items
# 0                             (nan)
# 1                    (nan, burgers)
# 2                       (cake, nan)
# 3                    (chicken, nan)
# 4                  (chocolate, nan)
# 5                    (cookies, nan)
# 6                (cooking oil, nan)
# 7                       (eggs, nan)
# 8                   (escalope, nan)
# 9               (french fries, nan)
# 10           (frozen smoothie, nan)
# 11         (nan, frozen vegetables)
# 12             (grated cheese, nan)
# 13                 (green tea, nan)
# 14               (ground beef, nan)
# 15            (low fat yogurt, nan)
# 16                      (milk, nan)
# 17             (mineral water, nan)
# 18                 (olive oil, nan)
# 19                  (pancakes, nan)
# 20                    (shrimp, nan)
# 21                      (soup, nan)
# 22                 (spaghetti, nan)
# 23                  (tomatoes, nan)
# 24                    (turkey, nan)
# ...

# %%
fs= pd.DataFrame(final, columns=["support","confidence","lift"] )
fs = fs.drop(columns=['support'])
fs = fs.drop(columns=['lift'])
fs
# Out:
#     confidence
# 0     0.999867
# 1     0.087188
# 2     0.081056
# 3     0.059992
# 4     0.163845
# 5     0.080389
# 6     0.051060
# 7     0.179709
# 8     0.079323
# 9     0.170911
# 10    0.063192
# 11    0.095321
# 12    0.052393
# 13    0.131982
# 14    0.098254
# 15    0.076390
# 16    0.129583
# 17    0.238235
# 18    0.065725
# 19    0.095054
# 20    0.071324
# 21    0.050527
# 22    0.174110
# 23    0.068391
# 24    0.062525
# 25    0.058526
# 26    0.052660
# 27    0.050927
# 28    0.059725

# %%
result = pd.concat([np, fs], axis=1, join='inner')
result
# Out:
#                               items  confidence
# 0                             (nan)    0.999867
# 1                    (nan, burgers)    0.087188
# 2                       (cake, nan)    0.081056
# 3                    (chicken, nan)    0.059992
# 4                  (chocolate, nan)    0.163845
# 5                    (cookies, nan)    0.080389
# 6                (cooking oil, nan)    0.051060
# 7                       (eggs, nan)    0.179709
# 8                   (escalope, nan)    0.079323
# 9               (french fries, nan)    0.170911
# 10           (frozen smoothie, nan)    0.063192
# 11         (nan, frozen vegetables)    0.095321
# 12             (grated cheese, nan)    0.052393
# 13                 (green tea, nan)    0.131982
# 14               (ground beef, nan)    0.098254
# 15            (low fat yogurt, nan)    0.076390
# 16                      (milk, nan)    0.129583
# 17             (mineral water, nan)    0.238235
# 18                 (olive oil, nan)    0.065725
# ...

# %%
df_sorted = result.sort_values(by='confidence', ascending=False)
df_sorted
# Out:
#                               items  confidence
# 0                             (nan)    0.999867
# 17             (mineral water, nan)    0.238235
# 7                       (eggs, nan)    0.179709
# 22                 (spaghetti, nan)    0.174110
# 9               (french fries, nan)    0.170911
# 4                  (chocolate, nan)    0.163845
# 13                 (green tea, nan)    0.131982
# 16                      (milk, nan)    0.129583
# 14               (ground beef, nan)    0.098254
# 11         (nan, frozen vegetables)    0.095321
# 19                  (pancakes, nan)    0.095054
# 1                    (nan, burgers)    0.087188
# 2                       (cake, nan)    0.081056
# 5                    (cookies, nan)    0.080389
# 8                   (escalope, nan)    0.079323
# 15            (low fat yogurt, nan)    0.076390
# 20                    (shrimp, nan)    0.071324
# 23                  (tomatoes, nan)    0.068391
# 18                 (olive oil, nan)    0.065725
# ...
